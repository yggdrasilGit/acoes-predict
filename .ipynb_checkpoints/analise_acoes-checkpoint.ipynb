# %% [markdown]
# # Definicão do Problema.

# %% [markdown]
# Este trabalha tem por objetivo, avaliar ações listadas na B3 `PETR4.SA, VALE3.SA, ITAB4.SA, WEGE3.SA ˆBVSP S&P500 e Dowjones USD/BRA` para os 5 anos, fatores economicos de ações de marcado podem ser analizado de formas como: `Ativos correlacionados` que nada mais é fatores macroeconomicos como: politicas fiscais, politicas cambiais, cenário geopolítico, acesso a capital; `Indicadores tecnicos`, como media movel, media movel expoencial, momentum de mercado; `Análise Fundamentalista`, como os relatorios de desempenho como `ROE` e `P/L` e `Noticias`.
#
# - Apresentaremos retorno acumulado de um determinado ativo;
# - Performace sobre cada ação;
# - E os periodos de volatividade de mercado.

# %%
import sys
print(sys.executable)
# Out:
# /Users/francismaralvesmartinsjunior/anaconda3/envs/acoes_pred/bin/python

# %% [markdown]
# # ============================================================
# # PLATAFORMA ÚNICA (1 arquivo) - OTIMIZADA + ROBUSTA (sem erro "zero-size array")
# # Dados -> Dataset (multi-horizonte) -> EDA -> Modelos -> Resultados
# # - Salva gráficos em JPEG
# # - Salva resultados em CSV
# # - Valida tamanho mínimo para evitar arrays vazios
# # ============================================================

# %%
# ============================================================
# PLATAFORMA ÚNICA (1 arquivo) - OTIMIZADA + ROBUSTA (sem erro "zero-size array")
# Dados -> Dataset (multi-horizonte) -> EDA -> Modelos -> Resultados
# - Salva gráficos em JPEG
# - Salva resultados em CSV
# - Valida tamanho mínimo para evitar arrays vazios
# ============================================================

import os
from dataclasses import dataclass
from datetime import datetime
import warnings

import numpy as np
import pandas as pd
import yfinance as yf

import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix

import statsmodels.api as sm

from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor

warnings.filterwarnings("ignore")







# ============================================================
# 4) EDA (com checagens para não quebrar)
# ============================================================

def plot_corr_heatmap(dataset: pd.DataFrame, horizon: int, cfg: Config):
    if dataset.shape[0] < 30 or dataset.shape[1] < cfg.min_features:
        print("⚠️ Heatmap pulado: dataset pequeno demais.")
        return

    corr = dataset.corr(numeric_only=True)
    if corr.empty:
        print("⚠️ Heatmap pulado: correlação vazia.")
        return

    fig = plt.figure(figsize=(14, 12))
    sns.heatmap(corr, vmin=-1, vmax=1, center=0, square=True, cmap="coolwarm", annot=False)
    plt.title(f"Matriz de Correlação - PETR4 (h={horizon})")
    plt.tight_layout()
    save_fig(fig, f"heatmap_h{horizon}", cfg)
    plt.show()

def plot_scatter_top(dataset: pd.DataFrame, horizon: int, cfg: Config, top_n=6):
    if dataset.shape[0] < 30 or dataset.shape[1] < cfg.min_features:
        print("⚠️ Scatter pulado: dataset pequeno demais.")
        return

    corr = dataset.corr(numeric_only=True)
    if "PETR4_pred" not in corr.columns:
        print("⚠️ Scatter pulado: correlação sem alvo.")
        return

    s = corr["PETR4_pred"].abs().sort_values(ascending=False).dropna()
    if len(s) < 2:
        print("⚠️ Scatter pulado: poucas variáveis correlacionadas.")
        return

    top_vars = s.head(min(top_n, len(s))).index

    fig = plt.figure(figsize=(10, 10))
    scatter_matrix(dataset[top_vars], alpha=0.6, diagonal="kde", figsize=(10, 10))
    plt.suptitle(f"Scatter Top Vars - PETR4 (h={horizon})", y=1.02)
    save_fig(fig, f"scatter_h{horizon}", cfg)
    plt.show()

def plot_decompose(series: pd.Series, horizon: int, cfg: Config):
    s = series.dropna().sort_index().astype(float)

    period = 12 if horizon >= 21 else 52
    min_len = period * cfg.decompose_cycles

    if len(s) < min_len:
        print(f"⚠️ Decomposição pulada: série curta ({len(s)} < {min_len}).")
        return

    res = sm.tsa.seasonal_decompose(s, model="additive", period=period, extrapolate_trend="freq")
    fig = res.plot()
    fig.set_size_inches(15, 8)
    fig.suptitle(f"Decomposição Sazonal (h={horizon}, period={period})", y=1.02)
    fig.tight_layout()
    save_fig(fig, f"decompose_h{horizon}", cfg)
    plt.show()

# ============================================================
# 5) MODELOS
# ============================================================

def get_models(cfg: Config):
    seed = cfg.seed
    return [
        ("LR", LinearRegression()),
        ("LASSO", Lasso(alpha=0.001, max_iter=5000, random_state=seed)),
        ("EN", ElasticNet(alpha=0.001, l1_ratio=0.5, max_iter=5000, random_state=seed)),
        ("KNN", KNeighborsRegressor(n_neighbors=10, weights="distance")),
        ("CART", DecisionTreeRegressor(max_depth=5, random_state=seed)),
        ("SVR", SVR(kernel="rbf", C=10, epsilon=0.01)),
        ("MLP", MLPRegressor(
            hidden_layer_sizes=(64, 32),
            activation="relu",
            solver="adam",
            learning_rate="adaptive",
            max_iter=2000,
            early_stopping=True,
            random_state=seed
        )),
        ("ABR", AdaBoostRegressor(n_estimators=300, learning_rate=0.05, random_state=seed)),
        ("GBR", GradientBoostingRegressor(n_estimators=300, learning_rate=0.05, max_depth=3, random_state=seed)),
        ("RFR", RandomForestRegressor(n_estimators=500, max_depth=6, n_jobs=-1, random_state=seed)),
        ("ETR", ExtraTreesRegressor(n_estimators=500, max_depth=6, n_jobs=-1, random_state=seed)),
    ]

# ============================================================
# 6) AVALIAÇÃO (robusta contra dataset pequeno)
# ============================================================

def safe_n_splits(n_train: int, desired: int, min_test: int):
    max_splits = (n_train // min_test) - 1
    return max(2, min(desired, max_splits))

def evaluate_models(X: pd.DataFrame, y: pd.Series, horizon: int, cfg: Config) -> pd.DataFrame:
    # checagens para evitar arrays vazios
    if X.empty or y.empty or len(X) != len(y):
        print("⚠️ Avaliação pulada: X/y vazios ou tamanhos incompatíveis.")
        return pd.DataFrame()

    split = int(len(X) * cfg.train_ratio)
    if split < cfg.min_test_size * 3:
        print("⚠️ Avaliação pulada: treino muito pequeno.")
        return pd.DataFrame()

    X_train, y_train = X.iloc[:split], y.iloc[:split]
    X_test, y_test = X.iloc[split:], y.iloc[split:]

    if len(X_test) < cfg.min_test_size:
        print("⚠️ Avaliação pulada: teste muito pequeno.")
        return pd.DataFrame()

    n_splits = safe_n_splits(len(X_train), cfg.desired_folds, cfg.min_test_size)
    if n_splits < 2:
        print("⚠️ Avaliação pulada: n_splits inválido.")
        return pd.DataFrame()

    tscv = TimeSeriesSplit(n_splits=n_splits)
    models = get_models(cfg)

    rows = []
    cv_map = {}

    for name, model in models:
        pipe = Pipeline([("scaler", StandardScaler()), ("model", model)])

        cv_mse = -cross_val_score(
            pipe,
            X_train,
            y_train,
            cv=tscv,
            scoring="neg_mean_squared_error",
            n_jobs=-1
        )

        # proteção extra
        if cv_mse.size == 0:
            print(f"⚠️ {name}: CV vazio, pulando.")
            continue

        cv_map[name] = cv_mse

        pipe.fit(X_train, y_train)
        train_mse = mean_squared_error(y_train, pipe.predict(X_train))
        test_mse = mean_squared_error(y_test, pipe.predict(X_test))

        rows.append({
            "Horizon": horizon,
            "Model": name,
            "CV_MSE_mean": float(np.mean(cv_mse)),
            "CV_MSE_std": float(np.std(cv_mse)),
            "Train_MSE": float(train_mse),
            "Test_MSE": float(test_mse),
            "n_splits": int(n_splits),
            "n_train": int(len(X_train)),
            "n_test": int(len(X_test)),
        })

    if not rows:
        print("⚠️ Nenhum modelo avaliável neste horizonte.")
        return pd.DataFrame()

    results = pd.DataFrame(rows).sort_values("Test_MSE").reset_index(drop=True)

    # salvar CSV
    if cfg.save_csv_results:
        path = os.path.join(cfg.results_dir, f"results_h{horizon}_{ts_now()}.csv")
        results.to_csv(path, index=False, encoding="utf-8")
        print("💾 CSV resultados salvo:", path)

    # boxplot (ordem do ranking)
    names_sorted = results["Model"].tolist()

    fig = plt.figure(figsize=(15, 8))
    plt.title(f"CV Results (MSE) - Horizon={horizon} | n_splits={n_splits}")
    plt.boxplot([cv_map[n] for n in names_sorted if n in cv_map])
    plt.xticks(range(1, len([n for n in names_sorted if n in cv_map]) + 1),
               [n for n in names_sorted if n in cv_map])
    plt.tight_layout()
    save_fig(fig, f"cv_boxplot_h{horizon}", cfg)
    plt.show()

    # barras Train vs Test
    ind = np.arange(len(names_sorted))
    width = 0.35

    fig = plt.figure(figsize=(15, 8))
    plt.title(f"Train vs Test (MSE) - Horizon={horizon}")
    plt.bar(ind - width/2, results["Train_MSE"].values, width=width, label="Train MSE")
    plt.bar(ind + width/2, results["Test_MSE"].values, width=width, label="Test MSE")
    plt.xticks(ind, names_sorted)
    plt.legend()
    plt.tight_layout()
    save_fig(fig, f"train_vs_test_h{horizon}", cfg)
    plt.show()

    print("\nResumo (ordenado por Test_MSE):")
    print(results.to_string(index=False, formatters={
        "CV_MSE_mean": "{:.6f}".format,
        "CV_MSE_std":  "{:.6f}".format,
        "Train_MSE":   "{:.6f}".format,
        "Test_MSE":    "{:.6f}".format,
    }))

    return results

# ============================================================
# 7) ORQUESTRAÇÃO MULTI-HORIZONTE (com validações)
# ============================================================

def min_rows_for_horizon(h: int, cfg: Config) -> int:
    return max(cfg.min_rows_rule_multiplier * h, cfg.min_rows_floor)

def run(cfg: Config):
    ensure_dirs(cfg)
    px = download_market_brl(cfg)

    all_results = []

    for h in cfg.horizons:
        print("\n" + "=" * 60)
        print(f"🚀 HORIZONTE: {h} dias")
        print("=" * 60)

        dataset, X, y, idx_cols = build_dataset_petr4(px, horizon=h, cfg=cfg)

        print("Índices incluídos:", idx_cols)
        print("Dataset:", dataset.shape, "| X:", X.shape, "| y:", y.shape)

        # ---- VALIDAÇÃO: evita array vazio (corr/min/max etc.)
        min_rows = min_rows_for_horizon(h, cfg)
        if len(dataset) < min_rows:
            print(f"⚠️ Pulando horizonte {h}: dataset pequeno ({len(dataset)} < {min_rows}).")
            continue

        # EDA (somente se tiver dados suficientes)
        plot_corr_heatmap(dataset, horizon=h, cfg=cfg)
        plot_scatter_top(dataset, horizon=h, cfg=cfg, top_n=6)
        plot_decompose(y, horizon=h, cfg=cfg)

        # ML (somente se tiver dados suficientes)
        res_h = evaluate_models(X, y, horizon=h, cfg=cfg)
        if not res_h.empty:
            all_results.append(res_h)

    if not all_results:
        print("\n❌ Nenhum horizonte gerou resultados. Diminua horizontes ou aumente years.")
        return px, pd.DataFrame(), pd.DataFrame()

    all_results = pd.concat(all_results, axis=0).reset_index(drop=True)

    if cfg.save_csv_results:
        path = os.path.join(cfg.results_dir, f"results_ALL_{ts_now()}.csv")
        all_results.to_csv(path, index=False, encoding="utf-8")
        print("\n💾 CSV resumo global salvo:", path)

    best = all_results.sort_values(["Horizon", "Test_MSE"]).groupby("Horizon").head(1)

    print("\n🏆 Melhor modelo por horizonte (menor Test_MSE):")
    print(best[["Horizon", "Model", "Test_MSE", "CV_MSE_mean", "CV_MSE_std", "n_splits", "n_train", "n_test"]]
          .to_string(index=False, formatters={
              "Test_MSE": "{:.6f}".format,
              "CV_MSE_mean": "{:.6f}".format,
              "CV_MSE_std": "{:.6f}".format
          }))

    return px, all_results, best

# ============================================================
# 8) EXECUÇÃO
# ============================================================

if __name__ == "__main__":
    # Dica: se você tiver poucos dados, comece com (5, 21, 63)
    # CFG.horizons = (5, 21, 63)

    px, all_results, best = run(CFG)
# Out:
# 💾 CSV preços salvo: outputs/resultados/prices_market_brl_2021-02-27_2026-02-27.csv
# Ticker      ITUB4_BRL  PETR4_BRL  USD_BRL  VALE3_BRL  WEGE3_BRL  IBOV_PONTOS  \
# Date
# 2021-03-01  16.028509   6.317828   5.5976  56.968662  34.874519     110335.0
# 2021-03-02  16.675592   6.314957   5.6407  58.719849  34.454243     111540.0
# 2021-03-03  16.714424   6.085218   5.6751  57.997417  34.427418     111184.0
# 2021-03-04  17.238565   6.381008   5.6175  57.136265  32.741817     112690.0
# 2021-03-05  17.879192   6.429826   5.6683  60.525631  32.656860     115202.0
#
# Ticker         SP500_BRL   DOWJONES_BRL
# Date
# 2021-03-01  21840.827949  176523.168935
# 2021-03-02  21831.144495  177070.139933
# 2021-03-03  21677.292232  177460.882172
# 2021-03-04  21169.379414  173716.354652
# 2021-03-05  21777.268753  178530.486500
#
# ============================================================
# 🚀 HORIZONTE: 5 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (1236, 12) | X: (1236, 11) | y: (1236,)
# 📷 Plot salvo: outputs/graficos/heatmap_h5_20260227_191023.jpeg
# 📷 Plot salvo: outputs/graficos/scatter_h5_20260227_191025.jpeg
# 📷 Plot salvo: outputs/graficos/decompose_h5_20260227_191026.jpeg
# 💾 CSV resultados salvo: outputs/resultados/results_h5_20260227_191048.csv
# 📷 Plot salvo: outputs/graficos/cv_boxplot_h5_20260227_191048.jpeg
# 📷 Plot salvo: outputs/graficos/train_vs_test_h5_20260227_191049.jpeg
# Resumo (ordenado por Test_MSE):
#  Horizon Model CV_MSE_mean CV_MSE_std Train_MSE Test_MSE  n_splits  n_train  n_test
#        5   ETR    0.002336   0.001613  0.001439 0.001561        10      988     248
#        5 LASSO    0.002396   0.001579  0.002007 0.001576        10      988     248
#        5   ABR    0.002354   0.001462  0.001771 0.001602        10      988     248
#        5   RFR    0.002408   0.001579  0.001284 0.001631        10      988     248
#        5    EN    0.002419   0.001587  0.001984 0.001645        10      988     248
#        5   KNN    0.002531   0.001415  0.000000 0.001748        10      988     248
#        5    LR    0.002507   0.001594  0.001972 0.001762        10      988     248
#        5  CART    0.002834   0.001883  0.001696 0.001805        10      988     248
#        5   GBR    0.002703   0.001677  0.000740 0.001844        10      988     248
#        5   SVR    0.004418   0.002858  0.000134 0.003618        10      988     248
#        5   MLP    0.010594   0.007621  0.001163 0.005215        10      988     248
#
# ============================================================
# 🚀 HORIZONTE: 21 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (1028, 12) | X: (1028, 11) | y: (1028,)
# 📷 Plot salvo: outputs/graficos/heatmap_h21_20260227_191050.jpeg
# 📷 Plot salvo: outputs/graficos/scatter_h21_20260227_191051.jpeg
# 📷 Plot salvo: outputs/graficos/decompose_h21_20260227_191052.jpeg
# 💾 CSV resultados salvo: outputs/resultados/results_h21_20260227_191105.csv
# 📷 Plot salvo: outputs/graficos/cv_boxplot_h21_20260227_191105.jpeg
# 📷 Plot salvo: outputs/graficos/train_vs_test_h21_20260227_191106.jpeg
# Resumo (ordenado por Test_MSE):
#  Horizon Model CV_MSE_mean CV_MSE_std Train_MSE Test_MSE  n_splits  n_train  n_test
#       21   ABR    0.012434   0.009239  0.004428 0.005338        10      822     206
#       21   RFR    0.015352   0.012247  0.002342 0.005558        10      822     206
#       21   ETR    0.013804   0.011779  0.003199 0.005591        10      822     206
#       21  CART    0.021754   0.017114  0.003903 0.005837        10      822     206
#       21   KNN    0.016939   0.010604  0.000000 0.006102        10      822     206
#       21   GBR    0.017385   0.011021  0.000934 0.007723        10      822     206
#       21 LASSO    0.021105   0.029396  0.006115 0.010428        10      822     206
#       21   MLP    0.066171   0.099246  0.000741 0.010619        10      822     206
#       21    EN    0.021194   0.028813  0.006046 0.011250        10      822     206
#       21    LR    0.019712   0.024892  0.006020 0.012254        10      822     206
#       21   SVR    0.018787   0.009768  0.000110 0.013750        10      822     206
#
# ============================================================
# 🚀 HORIZONTE: 63 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (482, 12) | X: (482, 11) | y: (482,)
# 📷 Plot salvo: outputs/graficos/heatmap_h63_20260227_191106.jpeg
# 📷 Plot salvo: outputs/graficos/scatter_h63_20260227_191108.jpeg
# 📷 Plot salvo: outputs/graficos/decompose_h63_20260227_191109.jpeg
# 💾 CSV resultados salvo: outputs/resultados/results_h63_20260227_191118.csv
# 📷 Plot salvo: outputs/graficos/cv_boxplot_h63_20260227_191119.jpeg
# 📷 Plot salvo: outputs/graficos/train_vs_test_h63_20260227_191119.jpeg
# Resumo (ordenado por Test_MSE):
#  Horizon Model CV_MSE_mean CV_MSE_std Train_MSE Test_MSE  n_splits  n_train  n_test
#       63   SVR    0.006924   0.009567  0.000088 0.004602        10      385      97
#       63   MLP    0.041942   0.044243  0.000615 0.009648        10      385      97
#       63  CART    0.010876   0.012238  0.000847 0.009800        10      385      97
#       63   ETR    0.006821   0.011728  0.000434 0.010934        10      385      97
#       63   KNN    0.007843   0.012063  0.000000 0.011469        10      385      97
#       63   GBR    0.007972   0.012318  0.000096 0.011515        10      385      97
#       63   RFR    0.007572   0.011015  0.000273 0.012001        10      385      97
#       63   ABR    0.008329   0.012188  0.000866 0.013514        10      385      97
#       63 LASSO    0.012445   0.017260  0.003299 0.019209        10      385      97
#       63    EN    0.013123   0.017776  0.003234 0.023458        10      385      97
#       63    LR    0.014297   0.018507  0.003209 0.028971        10      385      97
#
# ============================================================
# 🚀 HORIZONTE: 126 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (0, 12) | X: (0, 11) | y: (0,)
# ⚠️ Pulando horizonte 126: dataset pequeno (0 < 630).
#
# ============================================================
# 🚀 HORIZONTE: 252 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (0, 12) | X: (0, 11) | y: (0,)
# ⚠️ Pulando horizonte 252: dataset pequeno (0 < 1260).
#
# 💾 CSV resumo global salvo: outputs/resultados/results_ALL_20260227_191120.csv
#
# 🏆 Melhor modelo por horizonte (menor Test_MSE):
#  Horizon Model Test_MSE CV_MSE_mean CV_MSE_std  n_splits  n_train  n_test
#        5   ETR 0.001561    0.002336   0.001613        10      988     248
#       21   ABR 0.005338    0.012434   0.009239        10      822     206
#       63   SVR 0.004602    0.006924   0.009567        10      385      97

# %% [markdown]
# # ============================================================
# # 0) CONFIG
# # ============================================================

# %%
# ============================================================
# 0) CONFIG
# ============================================================

@dataclass
class Config:
    # dados
    years: int = 5
    auto_adjust: bool = True
    seed: int = 42

    # horizontes (dias úteis)
    horizons: tuple = (5, 21, 63, 126, 252)

    # validação
    train_ratio: float = 0.8
    desired_folds: int = 10
    min_test_size: int = 10  # tamanho mínimo do fold de validação

    # robustez (evita dataset vazio)
    min_rows_rule_multiplier: int = 5     # min_rows = max(multiplier*h, 100)
    min_rows_floor: int = 100             # mínimo absoluto
    min_features: int = 2                 # mínimo de colunas para rodar EDA
    decompose_cycles: int = 3             # precisa de 3 ciclos completos

    # dataset
    use_expanding_zscore: bool = True     # evita leakage
    downsample: bool = False              # NÃO recomendo (reduz amostras)

    # output
    out_dir: str = "outputs"
    plots_dir: str = "outputs/graficos"
    results_dir: str = "outputs/resultados"
    save_csv_prices: bool = True
    save_csv_results: bool = True
    save_plots: bool = True

CFG = Config()

# %% [markdown]
# # ============================================================
# # 1) UTIL: pastas + timestamp + salvar figura
# # ============================================================

# %%
def ensure_dirs(cfg: Config):
    os.makedirs(cfg.out_dir, exist_ok=True)
    os.makedirs(cfg.plots_dir, exist_ok=True)
    os.makedirs(cfg.results_dir, exist_ok=True)

def ts_now():
    return datetime.now().strftime("%Y%m%d_%H%M%S")

def save_fig(fig=None, name="plot", cfg: Config = CFG, dpi=300):
    if not cfg.save_plots:
        return None
    if fig is None:
        fig = plt.gcf()
    path = os.path.join(cfg.plots_dir, f"{name}_{ts_now()}.jpeg")
    fig.savefig(path, format="jpeg", dpi=dpi, bbox_inches="tight")
    print("📷 Plot salvo:", path)
    return path

# %% [markdown]
# # ============================================================
# # 2) DOWNLOAD + PREPARAÇÃO (BRL)
# # ============================================================

# %%
def download_market_brl(cfg: Config) -> pd.DataFrame:
    tickers = [
        "PETR4.SA", "VALE3.SA", "ITUB4.SA", "WEGE3.SA",
        "^BVSP", "^GSPC", "^DJI",
        "USDBRL=X"
    ]

    end = pd.Timestamp.today().normalize()
    start = end - pd.DateOffset(years=cfg.years)

    data = yf.download(
        tickers=tickers,
        start=start.strftime("%Y-%m-%d"),
        end=(end + pd.Timedelta(days=1)).strftime("%Y-%m-%d"),
        auto_adjust=cfg.auto_adjust,
        group_by="column",
        progress=False,
        threads=True
    )

    price_col = "Close" if cfg.auto_adjust else "Adj Close"
    px = data[price_col].copy().sort_index()

    # alinhar calendário BR/EUA
    px = px.ffill().dropna()
    if px.empty:
        raise RuntimeError("Download retornou DataFrame vazio. Verifique internet/tickers/período.")

    # EUA -> BRL
    if "^GSPC" in px.columns and "USDBRL=X" in px.columns:
        px["SP500_BRL"] = px["^GSPC"] * px["USDBRL=X"]
    if "^DJI" in px.columns and "USDBRL=X" in px.columns:
        px["DOWJONES_BRL"] = px["^DJI"] * px["USDBRL=X"]

    # renomear
    px = px.rename(columns={
        "PETR4.SA": "PETR4_BRL",
        "VALE3.SA": "VALE3_BRL",
        "ITUB4.SA": "ITUB4_BRL",
        "WEGE3.SA": "WEGE3_BRL",
        "^BVSP": "IBOV_PONTOS",
        "USDBRL=X": "USD_BRL",
    })

    # remover originais EUA
    for c in ["^GSPC", "^DJI"]:
        if c in px.columns:
            px.drop(columns=[c], inplace=True)

    if cfg.save_csv_prices:
        path = os.path.join(cfg.results_dir, f"prices_market_brl_{start.date()}_{end.date()}.csv")
        px.to_csv(path, encoding="utf-8")
        print("💾 CSV preços salvo:", path)

    print(px.head())
    return px

# %% [markdown]
# # ============================================================
# # 3) DATASET PETR4 (robusto)
# # ============================================================

# %%
def build_dataset_petr4(px: pd.DataFrame, horizon: int, cfg: Config):
    if "PETR4_BRL" not in px.columns:
        raise ValueError("Coluna obrigatória 'PETR4_BRL' não encontrada.")

    other_stocks = [c for c in ["VALE3_BRL", "ITUB4_BRL", "WEGE3_BRL"] if c in px.columns]
    fx_cols = [c for c in ["USD_BRL"] if c in px.columns]
    idx_cols = [c for c in ["IBOV_PONTOS", "SP500_BRL", "DOWJONES_BRL"] if c in px.columns]

    use_cols = ["PETR4_BRL"] + other_stocks + fx_cols + idx_cols
    df = px[use_cols].sort_index().copy()

    # log preços (evita -inf)
    if (df <= 0).any().any():
        df = df.where(df > 0).ffill().dropna()

    logp = np.log(df)

    # Y: retorno futuro
    Y = logp["PETR4_BRL"].diff(horizon).shift(-horizon).rename("PETR4_pred")

    parts = []

    # retornos ações ex-alvo
    if other_stocks:
        parts.append(logp[other_stocks].diff(horizon))

    # retorno câmbio
    if fx_cols:
        parts.append(logp[fx_cols].diff(horizon))

    # índices -> retorno -> z-score
    if idx_cols:
        idx_ret = logp[idx_cols].diff(horizon)
        if cfg.use_expanding_zscore:
            mu = idx_ret.expanding(min_periods=horizon).mean()
            sd = idx_ret.expanding(min_periods=horizon).std(ddof=0).replace(0, np.nan)
            Z = ((idx_ret - mu) / sd).add_prefix("Z_")
        else:
            sd = idx_ret.std(ddof=0).replace(0, np.nan)
            Z = ((idx_ret - idx_ret.mean()) / sd).add_prefix("Z_")
        parts.append(Z)

    # lags da própria PETR4
    lags = [horizon, horizon * 3, horizon * 6, horizon * 12]
    X_lags = pd.DataFrame(
        {
            "PETR4_DT": logp["PETR4_BRL"].diff(lags[0]),
            "PETR4_3DT": logp["PETR4_BRL"].diff(lags[1]),
            "PETR4_6DT": logp["PETR4_BRL"].diff(lags[2]),
            "PETR4_12DT": logp["PETR4_BRL"].diff(lags[3]),
        },
        index=df.index
    )
    parts.append(X_lags)

    X = pd.concat(parts, axis=1)
    dataset = pd.concat([Y, X], axis=1).dropna()

    if cfg.downsample:
        dataset = dataset.iloc[::horizon].copy()

    X_final = dataset.drop(columns=["PETR4_pred"])
    Y_final = dataset["PETR4_pred"]

    return dataset, X_final, Y_final, idx_cols

# %%
# ============================================================
# SALVAR MELHOR MODELO EM PKL (BINÁRIO)
# ============================================================

import joblib


def salvar_melhor_modelo_pkl(
    X: pd.DataFrame,
    y: pd.Series,
    results: pd.DataFrame,
    horizon: int,
    cfg: Config,
    nome_base: str = "PETR4"
):
    """
    Treina o melhor modelo com todos os dados e salva em .pkl
    """

    if results.empty:
        print("⚠️ Nenhum resultado disponível.")
        return None

    # Melhor modelo
    best_model_name = results.iloc[0]["Model"]
    print(f"\n🏆 Melhor modelo para horizonte {horizon}: {best_model_name}")

    # buscar modelo na lista
    models = dict(get_models(cfg))
    if best_model_name not in models:
        raise ValueError("Modelo não encontrado.")

    best_model = models[best_model_name]

    # pipeline com scaler (evita problemas futuros)
    pipeline = Pipeline([
        ("scaler", StandardScaler()),
        ("model", best_model)
    ])

    # treinar com todos os dados disponíveis
    pipeline.fit(X, y)

    # salvar binário
    filename = f"{nome_base}_best_model_h{horizon}.pkl"
    path = os.path.join(cfg.results_dir, filename)

    joblib.dump(pipeline, path)

    print("💾 Modelo salvo:", path)
    return path

# %%
# ============================================================
# CARREGAR MODELO E PREVER PETR4
# ============================================================

def carregar_modelo_pkl(path: str):
    return joblib.load(path)


def prever_petr4(model, X_novo: pd.DataFrame):
    """
    Retorna previsão de retorno futuro da PETR4
    """
    return model.predict(X_novo)

# %%
px, all_results, best = run(CFG)
# Out:
# 💾 CSV preços salvo: outputs/resultados/prices_market_brl_2021-02-27_2026-02-27.csv
# Ticker      ITUB4_BRL  PETR4_BRL  USD_BRL  VALE3_BRL  WEGE3_BRL  IBOV_PONTOS  \
# Date
# 2021-03-01  16.028502   6.317828   5.5976  56.968666  34.874531     110335.0
# 2021-03-02  16.675591   6.314957   5.6407  58.719852  34.454247     111540.0
# 2021-03-03  16.714424   6.085217   5.6751  57.997417  34.427410     111184.0
# 2021-03-04  17.238564   6.381007   5.6175  57.136261  32.741814     112690.0
# 2021-03-05  17.879185   6.429825   5.6683  60.525639  32.656857     115202.0
#
# Ticker         SP500_BRL   DOWJONES_BRL
# Date
# 2021-03-01  21840.827949  176523.168935
# 2021-03-02  21831.144495  177070.139933
# 2021-03-03  21677.292232  177460.882172
# 2021-03-04  21169.379414  173716.354652
# 2021-03-05  21777.268753  178530.486500
#
# ============================================================
# 🚀 HORIZONTE: 5 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (1236, 12) | X: (1236, 11) | y: (1236,)
# 📷 Plot salvo: outputs/graficos/heatmap_h5_20260227_191800.jpeg
# 📷 Plot salvo: outputs/graficos/scatter_h5_20260227_191801.jpeg
# 📷 Plot salvo: outputs/graficos/decompose_h5_20260227_191802.jpeg
# 💾 CSV resultados salvo: outputs/resultados/results_h5_20260227_191825.csv
# 📷 Plot salvo: outputs/graficos/cv_boxplot_h5_20260227_191825.jpeg
# 📷 Plot salvo: outputs/graficos/train_vs_test_h5_20260227_191825.jpeg
# Resumo (ordenado por Test_MSE):
#  Horizon Model CV_MSE_mean CV_MSE_std Train_MSE Test_MSE  n_splits  n_train  n_test
#        5   ETR    0.002336   0.001613  0.001439 0.001561        10      988     248
#        5 LASSO    0.002396   0.001579  0.002007 0.001576        10      988     248
#        5   ABR    0.002344   0.001435  0.001742 0.001615        10      988     248
#        5   RFR    0.002408   0.001579  0.001284 0.001631        10      988     248
#        5    EN    0.002419   0.001587  0.001984 0.001645        10      988     248
#        5   KNN    0.002531   0.001415  0.000000 0.001748        10      988     248
#        5    LR    0.002507   0.001594  0.001972 0.001762        10      988     248
#        5  CART    0.002834   0.001883  0.001696 0.001805        10      988     248
#        5   GBR    0.002692   0.001664  0.000740 0.001847        10      988     248
#        5   SVR    0.004418   0.002855  0.000134 0.003621        10      988     248
#        5   MLP    0.010586   0.007642  0.001303 0.005297        10      988     248
#
# ============================================================
# 🚀 HORIZONTE: 21 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (1028, 12) | X: (1028, 11) | y: (1028,)
# 📷 Plot salvo: outputs/graficos/heatmap_h21_20260227_191826.jpeg
# 📷 Plot salvo: outputs/graficos/scatter_h21_20260227_191827.jpeg
# 📷 Plot salvo: outputs/graficos/decompose_h21_20260227_191829.jpeg
# 💾 CSV resultados salvo: outputs/resultados/results_h21_20260227_191842.csv
# 📷 Plot salvo: outputs/graficos/cv_boxplot_h21_20260227_191842.jpeg
# 📷 Plot salvo: outputs/graficos/train_vs_test_h21_20260227_191842.jpeg
# Resumo (ordenado por Test_MSE):
#  Horizon Model CV_MSE_mean CV_MSE_std Train_MSE Test_MSE  n_splits  n_train  n_test
#       21   ABR    0.012692   0.009731  0.004461 0.005469        10      822     206
#       21   RFR    0.015337   0.012252  0.002342 0.005558        10      822     206
#       21   ETR    0.013799   0.011753  0.003199 0.005592        10      822     206
#       21  CART    0.021754   0.017114  0.003903 0.005837        10      822     206
#       21   KNN    0.016939   0.010604  0.000000 0.006102        10      822     206
#       21   GBR    0.017320   0.010844  0.000959 0.008295        10      822     206
#       21 LASSO    0.021105   0.029396  0.006115 0.010428        10      822     206
#       21   MLP    0.066178   0.099242  0.000740 0.010785        10      822     206
#       21    EN    0.021194   0.028813  0.006046 0.011250        10      822     206
#       21    LR    0.019712   0.024892  0.006020 0.012254        10      822     206
#       21   SVR    0.018761   0.009752  0.000110 0.013768        10      822     206
#
# ============================================================
# 🚀 HORIZONTE: 63 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (482, 12) | X: (482, 11) | y: (482,)
# 📷 Plot salvo: outputs/graficos/heatmap_h63_20260227_191843.jpeg
# 📷 Plot salvo: outputs/graficos/scatter_h63_20260227_191845.jpeg
# 📷 Plot salvo: outputs/graficos/decompose_h63_20260227_191846.jpeg
# 💾 CSV resultados salvo: outputs/resultados/results_h63_20260227_191855.csv
# 📷 Plot salvo: outputs/graficos/cv_boxplot_h63_20260227_191855.jpeg
# 📷 Plot salvo: outputs/graficos/train_vs_test_h63_20260227_191856.jpeg
# Resumo (ordenado por Test_MSE):
#  Horizon Model CV_MSE_mean CV_MSE_std Train_MSE Test_MSE  n_splits  n_train  n_test
#       63   SVR    0.006954   0.009601  0.000089 0.004615        10      385      97
#       63   MLP    0.041942   0.044243  0.000615 0.009648        10      385      97
#       63  CART    0.010876   0.012238  0.000847 0.009800        10      385      97
#       63   ETR    0.006822   0.011728  0.000434 0.010933        10      385      97
#       63   ABR    0.008353   0.011957  0.000847 0.010980        10      385      97
#       63   KNN    0.007843   0.012063  0.000000 0.011469        10      385      97
#       63   GBR    0.007916   0.012357  0.000096 0.011684        10      385      97
#       63   RFR    0.007560   0.010986  0.000274 0.012040        10      385      97
#       63 LASSO    0.012445   0.017260  0.003299 0.019209        10      385      97
#       63    EN    0.013123   0.017776  0.003234 0.023458        10      385      97
#       63    LR    0.014297   0.018507  0.003209 0.028971        10      385      97
#
# ============================================================
# 🚀 HORIZONTE: 126 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (0, 12) | X: (0, 11) | y: (0,)
# ⚠️ Pulando horizonte 126: dataset pequeno (0 < 630).
#
# ============================================================
# 🚀 HORIZONTE: 252 dias
# ============================================================
# Índices incluídos: ['IBOV_PONTOS', 'SP500_BRL', 'DOWJONES_BRL']
# Dataset: (0, 12) | X: (0, 11) | y: (0,)
# ⚠️ Pulando horizonte 252: dataset pequeno (0 < 1260).
#
# 💾 CSV resumo global salvo: outputs/resultados/results_ALL_20260227_191856.csv
#
# 🏆 Melhor modelo por horizonte (menor Test_MSE):
#  Horizon Model Test_MSE CV_MSE_mean CV_MSE_std  n_splits  n_train  n_test
#        5   ETR 0.001561    0.002336   0.001613        10      988     248
#       21   ABR 0.005469    0.012692   0.009731        10      822     206
#       63   SVR 0.004615    0.006954   0.009601        10      385      97

# %%
# salvar melhor modelo para cada horizonte
for h in CFG.horizons:
    res_h = all_results[all_results["Horizon"] == h]

    if res_h.empty:
        continue

    dataset, X, y, _ = build_dataset_petr4(px, horizon=h, cfg=CFG)

    salvar_melhor_modelo_pkl(X, y, res_h, horizon=h, cfg=CFG)
# Out:
# 🏆 Melhor modelo para horizonte 5: ETR
# 💾 Modelo salvo: outputs/resultados/PETR4_best_model_h5.pkl
#
# 🏆 Melhor modelo para horizonte 21: ABR
# 💾 Modelo salvo: outputs/resultados/PETR4_best_model_h21.pkl
#
# 🏆 Melhor modelo para horizonte 63: SVR
# 💾 Modelo salvo: outputs/resultados/PETR4_best_model_h63.pkl

# %%
# carregar modelo
model = carregar_modelo_pkl("outputs/resultados/PETR4_best_model_h21.pkl")

# preparar novos dados (mesma estrutura)
dataset, X, y, _ = build_dataset_petr4(px, horizon=63, cfg=CFG)

# usar últimos dados
X_last = X.iloc[-1:].copy()

# previsão
pred = prever_petr4(model, X_last)

print("Retorno previsto:", pred)
# Out:
# Retorno previsto: [-0.05791809]

# %%
preco_atual = px["PETR4_BRL"].iloc[-1]

preco_previsto = preco_atual * np.exp(pred[0])

print("Preço previsto:", preco_previsto)
# Out:
# Preço previsto: 37.11679434372783

# %%
# ============================================================
# GRÁFICO DE PREVISÃO PETR4
# ============================================================

def plot_previsao_petr4(
    px: pd.DataFrame,
    pred_retorno: float,
    horizon: int,
    salvar=True,
    cfg=CFG
):
    """
    Mostra gráfico com preço histórico + previsão futura.
    """

    # preço atual
    preco_atual = px["PETR4_BRL"].iloc[-1]

    # preço previsto
    preco_previsto = preco_atual * np.exp(pred_retorno)

    # histórico recente (para visualização)
    janela = 120  # dias
    historico = px["PETR4_BRL"].iloc[-janela:]

    # eixo futuro
    datas_futuras = pd.date_range(
        start=historico.index[-1],
        periods=horizon + 1,
        freq="B"
    )

    # gráfico
    fig = plt.figure(figsize=(15, 8))

    plt.plot(historico, label="Histórico PETR4", linewidth=2)

    # ponto atual
    plt.scatter(
        historico.index[-1],
        preco_atual,
        s=120,
        label="Preço atual"
    )

    # previsão
    plt.plot(
        [historico.index[-1], datas_futuras[-1]],
        [preco_atual, preco_previsto],
        linestyle="--",
        linewidth=3,
        label=f"Previsão {horizon} dias"
    )

    plt.scatter(
        datas_futuras[-1],
        preco_previsto,
        s=150,
        label="Preço previsto"
    )

    plt.title(f"Previsão PETR4 - Horizonte {horizon} dias")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # salvar
    if salvar:
        save_fig(fig, f"previsao_PETR4_h{horizon}", cfg)

    plt.show()

    print(f"\nPreço atual: {preco_atual:.2f}")
    print(f"Preço previsto: {preco_previsto:.2f}")
    print(f"Retorno previsto: {pred_retorno:.4f}")

# %%
# carregar modelo
model = carregar_modelo_pkl("outputs/resultados/PETR4_best_model_h21.pkl")

# preparar dataset
dataset, X, y, _ = build_dataset_petr4(px, horizon=21, cfg=CFG)

# pegar últimos dados
X_last = X.iloc[-1:]

# previsão
pred = model.predict(X_last)[0]

# gráfico

plot_previsao_petr4(px, pred, horizon=63)
# Out:
# 📷 Plot salvo: outputs/graficos/previsao_PETR4_h63_20260227_192501.jpeg
# Preço atual: 39.33
# Preço previsto: 39.35
# Retorno previsto: 0.0006

# %%
# ------------------------------------------------------------
# Colunas para o modelo ARIMA (adaptado ao Brasil)
# ------------------------------------------------------------
arima_cols = [
    "VALE3_BRL",
    "ITUB4_BRL",
    "WEGE3_BRL",
    "USD_BRL",
    "Z_IBOV_PONTOS",
    "Z_SP500_BRL",
    "Z_DOW_BRL"
]

# manter apenas as que existem
arima_cols = [c for c in arima_cols if c in X_train.columns]

print("Colunas ARIMA:", arima_cols)

# datasets
X_train_ARIMA = X_train.loc[:, arima_cols].copy()
X_test_ARIMA  = X_test.loc[:, arima_cols].copy()

# tamanhos
tr_len = len(X_train_ARIMA)
te_len = len(X_test_ARIMA)
to_len = len(X_final)

print("Train:", tr_len, "Test:", te_len, "Total:", to_len)
# Out:
# Colunas ARIMA: ['VALE3_BRL', 'ITUB4_BRL', 'WEGE3_BRL', 'USD_BRL', 'Z_IBOV_PONTOS', 'Z_SP500_BRL']
# Train: 28 Test: 8 Total: 36

# %%
from statsmodels.tsa.arima.model import ARIMA

# junta e limpa
df_tr = (
    y_train.to_frame("y")
    .join(X_train_ARIMA, how="inner")
    .dropna()
).copy()

# remove índice de datas (mata o warning de freq)
df_tr = df_tr.reset_index(drop=True)

y_tr = df_tr["y"]
X_tr = df_tr.drop(columns=["y"])

model_fit = ARIMA(endog=y_tr, exog=X_tr, order=(1, 0, 0)).fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   28
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                  36.324
# Date:                Fri, 27 Feb 2026   AIC                            -54.648
# Time:                        17:26:10   BIC                            -42.658
# Sample:                             0   HQIC                           -50.983
#                                  - 28
# Covariance Type:                  opg
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0525      0.016      3.318      0.001       0.021       0.083
# VALE3_BRL        -1.0263      0.199     -5.161      0.000      -1.416      -0.636
# ITUB4_BRL        -1.6340      0.789     -2.070      0.038      -3.181      -0.087
# WEGE3_BRL        -0.0623      0.213     -0.292      0.770      -0.480       0.356
# USD_BRL          -0.8187      1.052     -0.778      0.436      -2.880       1.243
# Z_IBOV_PONTOS     0.1079      0.051      2.112      0.035       0.008       0.208
# Z_SP500_BRL       0.0382      0.026      1.471      0.141      -0.013       0.089
# ar.L1            -0.5063      0.274     -1.849      0.064      -1.043       0.030
# sigma2            0.0043      0.002      2.701      0.007       0.001       0.007
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.47   Jarque-Bera (JB):                 0.88
# Prob(Q):                              0.49   Prob(JB):                         0.64
# Heteroskedasticity (H):               0.38   Skew:                             0.43
# Prob(H) (two-sided):                  0.16   Kurtosis:                         3.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# ------------------------------------------------------------
# Erro de treino
# ------------------------------------------------------------
from sklearn.metrics import mean_squared_error

# fittedvalues do ARIMA (alinhado com o treino usado no modelo)
y_train_aligned = y_tr  # usamos o y que foi passado ao ARIMA
error_Training_ARIMA = mean_squared_error(
    y_train_aligned,
    model_fit.fittedvalues
)

print("Training MSE ARIMA:", error_Training_ARIMA)


# ------------------------------------------------------------
# Previsão no conjunto de teste
# ------------------------------------------------------------
# número de observações
tr_len = len(y_tr)
te_len = len(X_test_ARIMA)
to_len = tr_len + te_len

# previsão fora da amostra
predicted = model_fit.predict(
    start=tr_len,
    end=to_len - 1,
    exog=X_test_ARIMA
)

# garantir alinhamento
predicted = predicted.iloc[:len(y_test)]

# ------------------------------------------------------------
# Erro de teste
# ------------------------------------------------------------
error_Test_ARIMA = mean_squared_error(y_test, predicted)

print("Test MSE ARIMA:", error_Test_ARIMA)
# Out:
# Training MSE ARIMA: 0.0043500492624331715
# Test MSE ARIMA: 0.01478097722664081

# %%
# ------------------------------------------------------------
# Preparação de sequências para LSTM
# ------------------------------------------------------------
seq_len = 2  # comprimento da sequência

# Targets (alinhados com as sequências)
Y_train_LSTM = np.array(y_train)[seq_len - 1:]
Y_test_LSTM  = np.array(y_test)

# ------------------------------------------------------------
# Estruturas de entrada
# ------------------------------------------------------------
n_features = X_train.shape[1]

X_train_LSTM = np.zeros(
    (X_train.shape[0] + 1 - seq_len, seq_len, n_features)
)

X_test_LSTM = np.zeros(
    (X_test.shape[0], seq_len, n_features)
)

# ------------------------------------------------------------
# Construção das sequências
# ------------------------------------------------------------
for i in range(seq_len):
    X_train_LSTM[:, i, :] = np.array(X_train)[
        i : X_train.shape[0] + i + 1 - seq_len, :
    ]

    X_test_LSTM[:, i, :] = np.array(X_final)[
        X_train.shape[0] + i - 1 : X_final.shape[0] + i + 1 - seq_len, :
    ]

print("X_train_LSTM:", X_train_LSTM.shape)
print("Y_train_LSTM:", Y_train_LSTM.shape)
print("X_test_LSTM:", X_test_LSTM.shape)
print("Y_test_LSTM:", Y_test_LSTM.shape)
# Out:
# X_train_LSTM: (27, 2, 11)
# Y_train_LSTM: (27,)
# X_test_LSTM: (8, 2, 11)
# Y_test_LSTM: (8,)

# %%
# ------------------------------------------------------------
# LSTM Network (completo)
# ------------------------------------------------------------
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import SGD, Adam

def create_LSTMmodel(learn_rate=0.01, momentum=0):
    model = Sequential()

    # camada LSTM
    model.add(
        LSTM(
            50,
            input_shape=(X_train_LSTM.shape[1], X_train_LSTM.shape[2])
        )
    )

    # opcional: ajuda a reduzir overfitting em dados financeiros
    model.add(Dropout(0.2))

    # camada densa
    model.add(Dense(1))

    # otimizador
    if momentum > 0:
        optimizer = SGD(learning_rate=learn_rate, momentum=momentum)
    else:
        optimizer = Adam(learning_rate=learn_rate)

    # compilação
    model.compile(loss="mse", optimizer=optimizer)

    return model


# ------------------------------------------------------------
# Treinamento
# ------------------------------------------------------------
LSTMModel = create_LSTMmodel(learn_rate=0.01, momentum=0)

LSTMModel_fit = LSTMModel.fit(
    X_train_LSTM,
    Y_train_LSTM,
    validation_data=(X_test_LSTM, Y_test_LSTM),
    epochs=330,
    batch_size=72,
    verbose=1,
    shuffle=False
)
# Out:
# Epoch 1/330
# /Users/francismaralvesmartinsjunior/anaconda3/envs/acoes_pred/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0246 - val_loss: 0.0073
# Epoch 2/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0110 - val_loss: 0.0067
# Epoch 3/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0178 - val_loss: 0.0069
# Epoch 4/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0145 - val_loss: 0.0072
# Epoch 5/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0118 - val_loss: 0.0075
# Epoch 6/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0108 - val_loss: 0.0087
# Epoch 7/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0089 - val_loss: 0.0104
# Epoch 8/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0093 - val_loss: 0.0120
# Epoch 9/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0102 - val_loss: 0.0131
# Epoch 10/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0097 - val_loss: 0.0136
# Epoch 11/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0059 - val_loss: 0.0138
# Epoch 12/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0105 - val_loss: 0.0134
# Epoch 13/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0080 - val_loss: 0.0130
# Epoch 14/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0064 - val_loss: 0.0124
# Epoch 15/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0075 - val_loss: 0.0117
# Epoch 16/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0075 - val_loss: 0.0113
# Epoch 17/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0058 - val_loss: 0.0111
# Epoch 18/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0056 - val_loss: 0.0112
# Epoch 19/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0063 - val_loss: 0.0116
# Epoch 20/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056 - val_loss: 0.0121
# Epoch 21/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0054 - val_loss: 0.0126
# Epoch 22/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0056 - val_loss: 0.0128
# Epoch 23/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0051 - val_loss: 0.0131
# Epoch 24/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0049 - val_loss: 0.0135
# Epoch 25/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0054 - val_loss: 0.0139
# Epoch 26/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0038 - val_loss: 0.0146
# Epoch 27/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0034 - val_loss: 0.0153
# Epoch 28/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0048 - val_loss: 0.0160
# Epoch 29/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0042 - val_loss: 0.0167
# Epoch 30/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0049 - val_loss: 0.0174
# Epoch 31/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0048 - val_loss: 0.0176
# Epoch 32/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0042 - val_loss: 0.0178
# Epoch 33/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0036 - val_loss: 0.0178
# Epoch 34/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0030 - val_loss: 0.0179
# Epoch 35/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0026 - val_loss: 0.0181
# Epoch 36/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0035 - val_loss: 0.0181
# Epoch 37/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0038 - val_loss: 0.0179
# Epoch 38/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0028 - val_loss: 0.0177
# Epoch 39/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0038 - val_loss: 0.0176
# Epoch 40/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0035 - val_loss: 0.0175
# Epoch 41/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0032 - val_loss: 0.0173
# Epoch 42/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0028 - val_loss: 0.0174
# Epoch 43/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0032 - val_loss: 0.0174
# Epoch 44/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0024 - val_loss: 0.0175
# Epoch 45/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0030 - val_loss: 0.0177
# Epoch 46/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0027 - val_loss: 0.0182
# Epoch 47/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0020 - val_loss: 0.0187
# Epoch 48/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0019 - val_loss: 0.0194
# Epoch 49/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0024 - val_loss: 0.0203
# Epoch 50/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0022 - val_loss: 0.0208
# Epoch 51/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0021 - val_loss: 0.0209
# Epoch 52/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0025 - val_loss: 0.0206
# Epoch 53/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0022 - val_loss: 0.0202
# Epoch 54/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0021 - val_loss: 0.0195
# Epoch 55/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0018 - val_loss: 0.0191
# Epoch 56/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0011 - val_loss: 0.0190
# Epoch 57/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0018 - val_loss: 0.0190
# Epoch 58/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0020 - val_loss: 0.0192
# Epoch 59/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0018 - val_loss: 0.0196
# Epoch 60/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0016 - val_loss: 0.0199
# Epoch 61/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0012 - val_loss: 0.0204
# Epoch 62/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0013 - val_loss: 0.0210
# Epoch 63/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0013 - val_loss: 0.0214
# Epoch 64/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0017 - val_loss: 0.0217
# Epoch 65/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0013 - val_loss: 0.0217
# Epoch 66/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 8.9462e-04 - val_loss: 0.0219
# Epoch 67/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0018 - val_loss: 0.0218
# Epoch 68/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0014 - val_loss: 0.0213
# Epoch 69/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0012 - val_loss: 0.0207
# Epoch 70/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.6834e-04 - val_loss: 0.0202
# Epoch 71/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0010 - val_loss: 0.0197
# Epoch 72/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 9.2876e-04 - val_loss: 0.0193
# Epoch 73/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.3985e-04 - val_loss: 0.0191
# Epoch 74/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0011 - val_loss: 0.0194
# Epoch 75/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0013 - val_loss: 0.0201
# Epoch 76/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 8.0745e-04 - val_loss: 0.0209
# Epoch 77/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 8.4130e-04 - val_loss: 0.0216
# Epoch 78/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 9.3367e-04 - val_loss: 0.0220
# Epoch 79/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.1573e-04 - val_loss: 0.0221
# Epoch 80/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.9242e-04 - val_loss: 0.0220
# Epoch 81/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0011 - val_loss: 0.0214
# Epoch 82/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.7158e-04 - val_loss: 0.0212
# Epoch 83/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010 - val_loss: 0.0215
# Epoch 84/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.8819e-04 - val_loss: 0.0215
# Epoch 85/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 7.3889e-04 - val_loss: 0.0214
# Epoch 86/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010 - val_loss: 0.0216
# Epoch 87/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0010 - val_loss: 0.0223
# Epoch 88/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010 - val_loss: 0.0228
# Epoch 89/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7.6959e-04 - val_loss: 0.0231
# Epoch 90/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0012 - val_loss: 0.0232
# Epoch 91/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.0214e-04 - val_loss: 0.0228
# Epoch 92/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 9.4283e-04 - val_loss: 0.0219
# Epoch 93/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0012 - val_loss: 0.0214
# Epoch 94/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0011 - val_loss: 0.0213
# Epoch 95/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 6.2988e-04 - val_loss: 0.0212
# Epoch 96/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.7571e-04 - val_loss: 0.0213
# Epoch 97/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 8.4584e-04 - val_loss: 0.0218
# Epoch 98/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.1083e-04 - val_loss: 0.0226
# Epoch 99/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0016 - val_loss: 0.0231
# Epoch 100/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0011 - val_loss: 0.0230
# Epoch 101/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.8254e-04 - val_loss: 0.0225
# Epoch 102/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.1249e-04 - val_loss: 0.0227
# Epoch 103/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.1900e-04 - val_loss: 0.0231
# Epoch 104/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.2122e-04 - val_loss: 0.0233
# Epoch 105/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.1158e-04 - val_loss: 0.0234
# Epoch 106/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.8043e-04 - val_loss: 0.0234
# Epoch 107/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.2367e-04 - val_loss: 0.0229
# Epoch 108/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 7.8298e-04 - val_loss: 0.0222
# Epoch 109/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 8.9852e-04 - val_loss: 0.0218
# Epoch 110/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 6.0855e-04 - val_loss: 0.0217
# Epoch 111/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.6877e-04 - val_loss: 0.0218
# Epoch 112/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.8805e-04 - val_loss: 0.0220
# Epoch 113/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.7121e-04 - val_loss: 0.0222
# Epoch 114/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.1202e-04 - val_loss: 0.0225
# Epoch 115/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.7001e-04 - val_loss: 0.0225
# Epoch 116/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.0195e-04 - val_loss: 0.0220
# Epoch 117/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.3905e-04 - val_loss: 0.0217
# Epoch 118/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 8.7179e-04 - val_loss: 0.0219
# Epoch 119/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.4986e-04 - val_loss: 0.0219
# Epoch 120/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 8.7701e-04 - val_loss: 0.0220
# Epoch 121/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.4429e-04 - val_loss: 0.0219
# Epoch 122/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 3.0561e-04 - val_loss: 0.0220
# Epoch 123/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.0938e-04 - val_loss: 0.0222
# Epoch 124/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.9090e-04 - val_loss: 0.0223
# Epoch 125/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.2589e-04 - val_loss: 0.0219
# Epoch 126/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.1274e-04 - val_loss: 0.0220
# Epoch 127/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.7850e-04 - val_loss: 0.0223
# Epoch 128/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.8156e-04 - val_loss: 0.0228
# Epoch 129/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0011 - val_loss: 0.0227
# Epoch 130/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.3223e-04 - val_loss: 0.0228
# Epoch 131/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.6072e-04 - val_loss: 0.0231
# Epoch 132/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.1178e-04 - val_loss: 0.0235
# Epoch 133/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.6884e-04 - val_loss: 0.0238
# Epoch 134/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 6.6320e-04 - val_loss: 0.0237
# Epoch 135/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.9719e-04 - val_loss: 0.0231
# Epoch 136/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.5785e-04 - val_loss: 0.0223
# Epoch 137/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.9182e-04 - val_loss: 0.0215
# Epoch 138/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.8783e-04 - val_loss: 0.0208
# Epoch 139/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.9227e-04 - val_loss: 0.0205
# Epoch 140/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0010 - val_loss: 0.0204
# Epoch 141/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.4281e-04 - val_loss: 0.0205
# Epoch 142/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.7590e-04 - val_loss: 0.0206
# Epoch 143/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.8161e-04 - val_loss: 0.0209
# Epoch 144/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 6.0040e-04 - val_loss: 0.0208
# Epoch 145/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.4909e-04 - val_loss: 0.0206
# Epoch 146/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.4389e-04 - val_loss: 0.0203
# Epoch 147/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.0879e-04 - val_loss: 0.0201
# Epoch 148/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.0664e-04 - val_loss: 0.0202
# Epoch 149/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.0505e-04 - val_loss: 0.0201
# Epoch 150/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 6.8211e-04 - val_loss: 0.0203
# Epoch 151/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.2222e-04 - val_loss: 0.0206
# Epoch 152/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.6713e-04 - val_loss: 0.0211
# Epoch 153/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.8854e-04 - val_loss: 0.0216
# Epoch 154/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 9.5519e-04 - val_loss: 0.0221
# Epoch 155/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.7416e-04 - val_loss: 0.0226
# Epoch 156/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.3342e-04 - val_loss: 0.0230
# Epoch 157/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.8308e-04 - val_loss: 0.0227
# Epoch 158/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 9.8372e-04 - val_loss: 0.0222
# Epoch 159/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 5.2640e-04 - val_loss: 0.0217
# Epoch 160/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.1103e-04 - val_loss: 0.0209
# Epoch 161/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.1864e-04 - val_loss: 0.0200
# Epoch 162/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.9031e-04 - val_loss: 0.0191
# Epoch 163/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.6707e-04 - val_loss: 0.0186
# Epoch 164/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.3515e-04 - val_loss: 0.0180
# Epoch 165/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.3962e-04 - val_loss: 0.0179
# Epoch 166/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.9297e-04 - val_loss: 0.0180
# Epoch 167/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.9361e-04 - val_loss: 0.0184
# Epoch 168/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.5680e-04 - val_loss: 0.0187
# Epoch 169/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.6866e-04 - val_loss: 0.0191
# Epoch 170/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.0590e-04 - val_loss: 0.0195
# Epoch 171/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.0135e-04 - val_loss: 0.0197
# Epoch 172/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.4600e-04 - val_loss: 0.0202
# Epoch 173/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.6683e-04 - val_loss: 0.0205
# Epoch 174/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.0390e-04 - val_loss: 0.0207
# Epoch 175/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 6.2916e-04 - val_loss: 0.0204
# Epoch 176/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.5977e-04 - val_loss: 0.0203
# Epoch 177/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.5384e-04 - val_loss: 0.0202
# Epoch 178/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.1091e-04 - val_loss: 0.0203
# Epoch 179/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.7008e-04 - val_loss: 0.0202
# Epoch 180/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.9551e-04 - val_loss: 0.0198
# Epoch 181/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.9627e-04 - val_loss: 0.0193
# Epoch 182/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.3255e-04 - val_loss: 0.0188
# Epoch 183/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.0982e-04 - val_loss: 0.0185
# Epoch 184/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.4278e-04 - val_loss: 0.0183
# Epoch 185/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.0510e-04 - val_loss: 0.0183
# Epoch 186/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.2275e-04 - val_loss: 0.0186
# Epoch 187/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.8313e-04 - val_loss: 0.0188
# Epoch 188/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.7502e-04 - val_loss: 0.0188
# Epoch 189/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7.4305e-04 - val_loss: 0.0189
# Epoch 190/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.2301e-04 - val_loss: 0.0191
# Epoch 191/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.6684e-04 - val_loss: 0.0193
# Epoch 192/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.4105e-04 - val_loss: 0.0194
# Epoch 193/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.7578e-04 - val_loss: 0.0193
# Epoch 194/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4.4183e-04 - val_loss: 0.0190
# Epoch 195/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.0112e-04 - val_loss: 0.0185
# Epoch 196/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.9090e-04 - val_loss: 0.0181
# Epoch 197/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.0003e-04 - val_loss: 0.0181
# Epoch 198/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.9960e-04 - val_loss: 0.0182
# Epoch 199/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.0856e-04 - val_loss: 0.0183
# Epoch 200/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.0489e-04 - val_loss: 0.0187
# Epoch 201/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.2344e-04 - val_loss: 0.0190
# Epoch 202/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.9956e-04 - val_loss: 0.0191
# Epoch 203/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 6.0834e-04 - val_loss: 0.0193
# Epoch 204/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.2310e-04 - val_loss: 0.0191
# Epoch 205/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.5472e-04 - val_loss: 0.0191
# Epoch 206/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.1853e-04 - val_loss: 0.0194
# Epoch 207/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.7958e-04 - val_loss: 0.0196
# Epoch 208/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.7186e-04 - val_loss: 0.0195
# Epoch 209/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.4407e-04 - val_loss: 0.0194
# Epoch 210/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6345e-04 - val_loss: 0.0190
# Epoch 211/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.9225e-04 - val_loss: 0.0188
# Epoch 212/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.1233e-04 - val_loss: 0.0185
# Epoch 213/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.3225e-04 - val_loss: 0.0183
# Epoch 214/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.6705e-04 - val_loss: 0.0184
# Epoch 215/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.0344e-04 - val_loss: 0.0185
# Epoch 216/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.0658e-04 - val_loss: 0.0186
# Epoch 217/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9678e-04 - val_loss: 0.0189
# Epoch 218/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.4307e-04 - val_loss: 0.0194
# Epoch 219/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.7403e-04 - val_loss: 0.0195
# Epoch 220/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.3917e-04 - val_loss: 0.0192
# Epoch 221/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.9957e-04 - val_loss: 0.0186
# Epoch 222/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.3069e-04 - val_loss: 0.0180
# Epoch 223/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.4977e-04 - val_loss: 0.0177
# Epoch 224/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.0498e-04 - val_loss: 0.0177
# Epoch 225/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.8567e-04 - val_loss: 0.0180
# Epoch 226/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.9270e-04 - val_loss: 0.0185
# Epoch 227/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.5033e-04 - val_loss: 0.0188
# Epoch 228/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.9062e-04 - val_loss: 0.0189
# Epoch 229/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.6246e-04 - val_loss: 0.0190
# Epoch 230/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4.1492e-04 - val_loss: 0.0187
# Epoch 231/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 7.8660e-04 - val_loss: 0.0184
# Epoch 232/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.8646e-04 - val_loss: 0.0183
# Epoch 233/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.4310e-04 - val_loss: 0.0182
# Epoch 234/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.0530e-04 - val_loss: 0.0177
# Epoch 235/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.0169e-04 - val_loss: 0.0174
# Epoch 236/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.5741e-04 - val_loss: 0.0172
# Epoch 237/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6148e-04 - val_loss: 0.0169
# Epoch 238/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.6836e-04 - val_loss: 0.0166
# Epoch 239/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.7101e-04 - val_loss: 0.0166
# Epoch 240/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.1584e-04 - val_loss: 0.0165
# Epoch 241/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.4534e-04 - val_loss: 0.0167
# Epoch 242/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.7114e-04 - val_loss: 0.0170
# Epoch 243/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.0468e-04 - val_loss: 0.0174
# Epoch 244/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.3158e-04 - val_loss: 0.0179
# Epoch 245/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.7133e-04 - val_loss: 0.0181
# Epoch 246/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.6672e-04 - val_loss: 0.0185
# Epoch 247/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.6378e-04 - val_loss: 0.0192
# Epoch 248/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.8933e-04 - val_loss: 0.0198
# Epoch 249/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.6273e-04 - val_loss: 0.0199
# Epoch 250/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.6822e-04 - val_loss: 0.0196
# Epoch 251/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.1126e-04 - val_loss: 0.0197
# Epoch 252/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.1145e-04 - val_loss: 0.0194
# Epoch 253/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.9817e-04 - val_loss: 0.0188
# Epoch 254/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.7379e-04 - val_loss: 0.0182
# Epoch 255/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.5031e-04 - val_loss: 0.0175
# Epoch 256/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.6509e-04 - val_loss: 0.0170
# Epoch 257/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.4683e-04 - val_loss: 0.0167
# Epoch 258/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0076e-04 - val_loss: 0.0165
# Epoch 259/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.7901e-04 - val_loss: 0.0166
# Epoch 260/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.7386e-04 - val_loss: 0.0166
# Epoch 261/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.8152e-04 - val_loss: 0.0167
# Epoch 262/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.1921e-04 - val_loss: 0.0168
# Epoch 263/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.8031e-04 - val_loss: 0.0168
# Epoch 264/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.2628e-04 - val_loss: 0.0168
# Epoch 265/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.3801e-04 - val_loss: 0.0170
# Epoch 266/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.6208e-04 - val_loss: 0.0170
# Epoch 267/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.9002e-04 - val_loss: 0.0172
# Epoch 268/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.5367e-04 - val_loss: 0.0172
# Epoch 269/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.8644e-04 - val_loss: 0.0175
# Epoch 270/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.7980e-04 - val_loss: 0.0176
# Epoch 271/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.4398e-04 - val_loss: 0.0175
# Epoch 272/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.0212e-04 - val_loss: 0.0173
# Epoch 273/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.0629e-04 - val_loss: 0.0172
# Epoch 274/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6314e-04 - val_loss: 0.0170
# Epoch 275/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.2099e-04 - val_loss: 0.0168
# Epoch 276/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.2407e-04 - val_loss: 0.0168
# Epoch 277/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.0620e-04 - val_loss: 0.0169
# Epoch 278/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.0412e-04 - val_loss: 0.0172
# Epoch 279/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.5823e-04 - val_loss: 0.0173
# Epoch 280/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.7885e-04 - val_loss: 0.0174
# Epoch 281/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.5333e-04 - val_loss: 0.0175
# Epoch 282/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.7262e-04 - val_loss: 0.0176
# Epoch 283/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.0836e-04 - val_loss: 0.0176
# Epoch 284/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.1931e-04 - val_loss: 0.0181
# Epoch 285/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9857e-04 - val_loss: 0.0186
# Epoch 286/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.5716e-04 - val_loss: 0.0188
# Epoch 287/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.8524e-04 - val_loss: 0.0189
# Epoch 288/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.0095e-04 - val_loss: 0.0184
# Epoch 289/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.0169e-04 - val_loss: 0.0181
# Epoch 290/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.8815e-04 - val_loss: 0.0175
# Epoch 291/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.5322e-04 - val_loss: 0.0171
# Epoch 292/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0918e-04 - val_loss: 0.0169
# Epoch 293/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.2689e-04 - val_loss: 0.0166
# Epoch 294/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.7229e-04 - val_loss: 0.0163
# Epoch 295/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.1179e-04 - val_loss: 0.0161
# Epoch 296/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.1772e-04 - val_loss: 0.0162
# Epoch 297/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.3927e-04 - val_loss: 0.0164
# Epoch 298/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.0467e-04 - val_loss: 0.0169
# Epoch 299/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.4265e-04 - val_loss: 0.0173
# Epoch 300/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.1985e-04 - val_loss: 0.0173
# Epoch 301/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.5917e-04 - val_loss: 0.0172
# Epoch 302/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.0456e-04 - val_loss: 0.0170
# Epoch 303/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.7085e-04 - val_loss: 0.0168
# Epoch 304/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.4694e-04 - val_loss: 0.0164
# Epoch 305/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.3508e-04 - val_loss: 0.0161
# Epoch 306/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.6986e-04 - val_loss: 0.0163
# Epoch 307/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.5198e-04 - val_loss: 0.0166
# Epoch 308/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.8792e-04 - val_loss: 0.0166
# Epoch 309/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.7805e-04 - val_loss: 0.0167
# Epoch 310/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.1080e-04 - val_loss: 0.0169
# Epoch 311/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.8242e-04 - val_loss: 0.0170
# Epoch 312/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4906e-04 - val_loss: 0.0170
# Epoch 313/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.8182e-04 - val_loss: 0.0165
# Epoch 314/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.7006e-04 - val_loss: 0.0161
# Epoch 315/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.9343e-04 - val_loss: 0.0157
# Epoch 316/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.6022e-04 - val_loss: 0.0159
# Epoch 317/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.7230e-04 - val_loss: 0.0161
# Epoch 318/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.4621e-04 - val_loss: 0.0165
# Epoch 319/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.4986e-04 - val_loss: 0.0169
# Epoch 320/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.1617e-04 - val_loss: 0.0172
# Epoch 321/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.6947e-04 - val_loss: 0.0175
# Epoch 322/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.8577e-04 - val_loss: 0.0175
# Epoch 323/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.8229e-04 - val_loss: 0.0174
# Epoch 324/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.9816e-04 - val_loss: 0.0173
# Epoch 325/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.8822e-04 - val_loss: 0.0171
# Epoch 326/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.5082e-04 - val_loss: 0.0171
# Epoch 327/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.2744e-04 - val_loss: 0.0171
# Epoch 328/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.0798e-04 - val_loss: 0.0171
# Epoch 329/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.6640e-04 - val_loss: 0.0173
# Epoch 330/330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4750e-04 - val_loss: 0.0175

# %%
# ------------------------------------------------------------
# Gráfico da loss do LSTM (treino vs validação)
# ------------------------------------------------------------
from matplotlib import pyplot

pyplot.figure(figsize=(10, 6))

pyplot.plot(LSTMModel_fit.history["loss"], label="Train")
pyplot.plot(LSTMModel_fit.history["val_loss"], "--", label="Validation")

pyplot.legend()
pyplot.title("LSTM Training vs Validation Loss")
pyplot.xlabel("Epoch")
pyplot.ylabel("MSE")

pyplot.show()

# %%
# ------------------------------------------------------------
# Avaliação do LSTM
# ------------------------------------------------------------
from sklearn.metrics import mean_squared_error

# erro no treino
yhat_train = LSTMModel.predict(X_train_LSTM)
error_Training_LSTM = mean_squared_error(
    Y_train_LSTM,
    yhat_train
)

print("Training MSE LSTM:", error_Training_LSTM)


# ------------------------------------------------------------
# Previsão no teste
# ------------------------------------------------------------
predicted = LSTMModel.predict(X_test_LSTM)

# garantir formato correto (às vezes sai como vetor 2D)
predicted = predicted.flatten()

# erro no teste
error_Test_LSTM = mean_squared_error(
    Y_test_LSTM,
    predicted
)

print("Test MSE LSTM:", error_Test_LSTM)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Training MSE LSTM: 7.282025334646311e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Test MSE LSTM: 0.0174512551473685

# %%
# ------------------------------------------------------------
# Adicionar ARIMA e LSTM à comparação
# ------------------------------------------------------------
test_results.append(error_Test_ARIMA)
test_results.append(error_Test_LSTM)

train_results.append(error_Training_ARIMA)
train_results.append(error_Training_LSTM)

names.append("ARIMA")
names.append("LSTM")

# %%
# ------------------------------------------------------------
# Grid search simples para ARIMA/ARIMAX (com exógenas)
# Adaptado ao seu pipeline (y_train / X_train_ARIMA) e sem aspas “curvas”
# ------------------------------------------------------------
import warnings
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# (opcional, recomendado) alinhar e remover NaNs uma vez
df_tr = (
    y_train.to_frame("y")
    .join(X_train_ARIMA, how="inner")
    .dropna()
).reset_index(drop=True)  # remove DateTimeIndex para evitar warning de freq

y_tr = df_tr["y"]
X_tr = df_tr.drop(columns=["y"])

def evaluate_arima_model(arima_order):
    model = ARIMA(endog=y_tr, exog=X_tr, order=arima_order)
    model_fit = model.fit()
    mse = mean_squared_error(y_tr, model_fit.fittedvalues)
    return mse

def evaluate_models(p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None

    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p, d, q)
                try:
                    mse = evaluate_arima_model(order)
                    print(f"ARIMA{order} MSE={mse:.7f}")
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                except Exception:
                    continue

    print(f"Best ARIMA{best_cfg} MSE={best_score:.7f}")
    return best_cfg, best_score

# ------------------------------------------------------------
# Avaliação de parâmetros
# ------------------------------------------------------------
p_values = [0, 1, 2]
d_values = range(0, 2)
q_values = range(0, 2)

warnings.filterwarnings("ignore")
best_cfg, best_score = evaluate_models(p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=0.0054263
# ARIMA(0, 0, 1) MSE=0.0036616
# ARIMA(0, 1, 0) MSE=0.0123205
# ARIMA(0, 1, 1) MSE=0.0065170
# ARIMA(1, 0, 0) MSE=0.0043500
# ARIMA(1, 0, 1) MSE=0.0038254
# ARIMA(1, 1, 0) MSE=0.0080149
# ARIMA(1, 1, 1) MSE=0.0053811
# ARIMA(2, 0, 0) MSE=0.0038111
# ARIMA(2, 0, 1) MSE=0.0037223
# ARIMA(2, 1, 0) MSE=0.0066961
# ARIMA(2, 1, 1) MSE=0.0050843
# Best ARIMA(0, 0, 1) MSE=0.0036616

# %%
# ------------------------------------------------------------
# ARIMA/ARIMAX "tuned" (2,0,1) com exógenas + MSE no teste
# (adaptado ao seu pipeline: y_train / y_test)
# ------------------------------------------------------------
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import pandas as pd

# alinhar treino (mesmo índice, sem NaN) e remover DateTimeIndex (evita warning de freq)
df_tr = (
    y_train.to_frame("y")
    .join(X_train_ARIMA, how="inner")
    .dropna()
).reset_index(drop=True)

y_tr = df_tr["y"]
X_tr = df_tr.drop(columns=["y"])

# alinhar teste também (importante!)
df_te = (
    y_test.to_frame("y")
    .join(X_test_ARIMA, how="inner")
    .dropna()
).reset_index(drop=True)

y_te = df_te["y"]
X_te = df_te.drop(columns=["y"])

# ------------------------------------------------------------
# Treinar modelo ajustado
# ------------------------------------------------------------
modelARIMA_tuned = ARIMA(endog=y_tr, exog=X_tr, order=(2, 0, 1))
model_fit_tuned = modelARIMA_tuned.fit()

# ------------------------------------------------------------
# Prever no teste (fora da amostra)
# ------------------------------------------------------------
tr_len = len(y_tr)
te_len = len(y_te)

predicted_tuned = model_fit_tuned.predict(
    start=tr_len,
    end=tr_len + te_len - 1,
    exog=X_te
).to_numpy()

# ------------------------------------------------------------
# MSE no teste
# ------------------------------------------------------------
mse_test = mean_squared_error(y_te.to_numpy(), predicted_tuned)
print("Test MSE (ARIMA tuned):", mse_test)
# Out:
# Test MSE (ARIMA tuned): 0.014774231560071025

# %%
# ------------------------------------------------------------
# Plot: valores reais vs previstos (ARIMA tuned)
# ------------------------------------------------------------
from matplotlib import pyplot
import numpy as np
import pandas as pd

# garantir que predicted seja série com o mesmo índice
predicted_series = pd.Series(
    predicted_tuned,
    index=y_test.index
)

# transformar retornos log em preço relativo acumulado
actual = np.exp(y_test).cumprod()
predicted = np.exp(predicted_series).cumprod()

# gráfico
pyplot.figure(figsize=(8, 5))

pyplot.plot(actual, "r", label="Actual")
pyplot.plot(predicted, "b--", label="Predicted")

pyplot.legend()
pyplot.title("ARIMA Tuned: Actual vs Predicted (PETR4)")
pyplot.xlabel("Time")
pyplot.ylabel("Relative Price")

pyplot.show()

# %%
# Out:
# Faltando: []
# px['PETR4_BRL'] shape: (1248,)
# X_test_ARIMA shape: (8, 6)
# 5 dias: preço previsto no final = 24.52 BRL
# 3 meses: preço previsto no final = 0.05 BRL
# 1 ano: preço previsto no final = 0.00 BRL

# %%
# Retornos diários
ret = px.pct_change().dropna(how="all")

# Retorno acumulado (base 1.0)
cumret = (1 + ret).cumprod()

# Performance (estatísticas)
ann_factor = 252  # pregões
perf = pd.DataFrame(index=px.columns)
perf["Cumulative Return"] = cumret.iloc[-1] - 1
perf["Annualized Return"] = (1 + perf["Cumulative Return"]) ** (ann_factor / len(ret)) - 1
perf["Annualized Volatility"] = ret.std() * np.sqrt(ann_factor)
perf["Sharpe (rf=0)"] = perf["Annualized Return"] / perf["Annualized Volatility"]
perf["Max Drawdown"] = (cumret / cumret.cummax() - 1).min()

# Volatilidade por períodos (rolling)
vol_21d = ret.rolling(21).std() * np.sqrt(ann_factor)
vol_63d = ret.rolling(63).std() * np.sqrt(ann_factor)

# Indicadores técnicos (SMA, EMA, Momentum)
def indicators(series: pd.Series) -> pd.DataFrame:
    df = pd.DataFrame(index=series.index)
    df["price"] = series
    df["SMA_20"] = series.rolling(20).mean()
    df["SMA_50"] = series.rolling(50).mean()
    df["EMA_20"] = series.ewm(span=20, adjust=False).mean()
    df["EMA_50"] = series.ewm(span=50, adjust=False).mean()
    df["Momentum_20"] = series / series.shift(20) - 1
    df["Return"] = series.pct_change()
    return df

tech = {t: indicators(px[t].dropna()) for t in px.columns}

# Correlação entre ativos (retornos)
corr = ret.corr()

# ---- Fundamentais simples via yfinance (se disponível) ----
fund_cols = ["shortName", "sector", "industry", "marketCap", "trailingPE", "forwardPE", "priceToBook", "returnOnEquity"]
fund = []
for t in tickers:
    try:
        info = yf.Ticker(t).info
        row = {"Ticker": t}
        for c in fund_cols:
            row[c] = info.get(c, np.nan)
        fund.append(row)
    except Exception:
        fund.append({"Ticker": t, **{c: np.nan for c in fund_cols}})
fund = pd.DataFrame(fund).set_index("Ticker")

# ---- Exportar tudo para Excel ----
with pd.ExcelWriter(out_xlsx, engine="openpyxl") as writer:
    px.to_excel(writer, sheet_name="Prices_AdjClose")
    ret.to_excel(writer, sheet_name="Returns_Daily")
    cumret.to_excel(writer, sheet_name="Cumulative_Return")
    perf.to_excel(writer, sheet_name="Performance_Summary")
    vol_21d.to_excel(writer, sheet_name="Vol_21d_Ann")
    vol_63d.to_excel(writer, sheet_name="Vol_63d_Ann")
    corr.to_excel(writer, sheet_name="Correlation")
    fund.to_excel(writer, sheet_name="Fundamentals")

    # indicadores técnicos em abas separadas (uma por ativo)
    for t, df in tech.items():
        sheet = (t.replace("^", "").replace("=X", "_FX").replace(".SA", "_SA"))[:31]
        df.to_excel(writer, sheet_name=sheet)

print(f"OK! Arquivo gerado: {out_xlsx}")
print("Datas:", px.index.min().date(), "->", px.index.max().date())
# Out:
# /var/folders/gn/dx1c6sms7t97njh2f0xm8bkm0000gn/T/ipykernel_4878/1268233514.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = px.pct_change().dropna(how="all")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 52
#      49 fund = pd.DataFrame(fund).set_index("Ticker")
#      51 # ---- Exportar tudo para Excel ----
# ---> 52 with pd.ExcelWriter(out_xlsx, engine="openpyxl") as writer:
#      53     px.to_excel(writer, sheet_name="Prices_AdjClose")
#      54     ret.to_excel(writer, sheet_name="Returns_Daily")
#
# NameError: name 'out_xlsx' is not defined
